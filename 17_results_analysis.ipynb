# %%
"""
Скрипт за анализ на влиянието на земното покритие върху тежестта на пожарите.
Показва резултатите инлайн в Jupyter и ги записва като файлове.
"""

import pandas as pd
import numpy as np
from scipy import stats
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from IPython.display import display, HTML

# ====================== НАСТРОЙКИ ======================
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 8)
sns.set_style("whitegrid")

BASE_DIR = r"D:\data\master_thesis\exports\sentinel2_fire_images\nbr_analysis"
os.chdir(BASE_DIR)
OUTPUT_DIR = os.path.join(BASE_DIR, "analysis_output")
os.makedirs(OUTPUT_DIR, exist_ok=True)

# ====================== 1. ЗАРЕЖДАНЕ ======================
df = pd.read_csv("fire_statistics_summary.csv")

print("=== РАЗМЕРНОСТ И ИНФОРМАЦИЯ ЗА ДАННИТЕ ===")
print(f"Shape: {df.shape}")
display(HTML(df.info()))

# Запис във файл
with open(os.path.join(OUTPUT_DIR, "data_info.txt"), "w", encoding="utf-8") as f:
    f.write(f"Размерност: {df.shape}\n\n")
    import io
    buf = io.StringIO()
    df.info(buf=buf)
    f.write(buf.getvalue())

# ====================== 2. ПОДГОТОВКА ======================
покрития = ['Field/Agriculture', 'Coniferous_Forest', 'Deciduous_Forest']
метрики_тежест = ['ModerateSeverity_%', 'HighSeverity_%', 'ModerateHigh_%']
дании_по_метрика = {
    m: df[[f"{p}_{m}" for p in покрития]].rename(
        columns=lambda c: c.split('_', 1)[1].replace('_%', '')
    )
    for m in метрики_тежест
}

# ====================== 3. ДЕСКРИПТИВНА СТАТИСТИКА ======================
print("\n=== ДЕСКРИПТИВНА СТАТИСТИКА ===")
for m in метрики_тежест:
    print(f"\n--- {m} ---")
    desc = дании_по_метрика[m].describe().round(2)
    display(desc)

# Запис в текстов файл
with open(os.path.join(OUTPUT_DIR, "descriptive_stats.txt"), "w", encoding="utf-8") as f:
    f.write("Средни стойности на показателите за тежест по тип покритие\n" + "="*60 + "\n")
    for m in метрики_тежест:
        f.write(f"\n--- {m} ---\n")
        f.write(дании_по_метрика[m].describe().round(2).to_string() + "\n")

# ====================== 4. FRIEDMAN ======================
print("\n=== FRIEDMAN TEST ===")
friedman_res = []
for m in метрики_тежест:
    d = дании_по_метрика[m]
    stat, p = stats.friedmanchisquare(d.iloc[:, 0], d.iloc[:, 1], d.iloc[:, 2])
    sig = "ДА" if p < 0.05 else "НЕ"
    friedman_res.append((m, stat, p, sig))
    print(f"{m}: stat={stat:.3f}, p={p:.4f} -> значима разлика? {sig}")

# Запис във файл
with open(os.path.join(OUTPUT_DIR, "friedman_test.txt"), "w", encoding="utf-8") as f:
    f.write("Friedman test\n" + "="*60 + "\n")
    for m, stat, p, sig in friedman_res:
        f.write(f"{m}: stat={stat:.3f}, p={p:.4f} -> значима разлика? {sig}\n")

# ====================== 5. POST-HOC WILCOXON ======================
alpha_bonf = 0.05 / 3
print("\n=== POST-HOC (WILCOXON С BONFERRONI КОРЕКЦИЯ) ===")
for m in метрики_тежест:
    d = дании_по_метрика[m]
    _, p_f = stats.friedmanchisquare(d.iloc[:, 0], d.iloc[:, 1], d.iloc[:, 2])
    if p_f >= 0.05:
        print(f"{m}: Friedman незначим – пропускаме post-hoc.")
        continue
    print(f"\n--- {m} (Friedman p={p_f:.4f}) ---")
    pairs = [(0, 1), (0, 2), (1, 2)]
    names = d.columns
    for i, j in pairs:
        w_stat, w_p = stats.wilcoxon(d.iloc[:, i], d.iloc[:, j])
        sig = "ДА" if w_p < alpha_bonf else "НЕ"
        print(f"{names[i]} vs {names[j]}: W={w_stat:.3f}, p={w_p:.4f} -> значима? {sig}")

# Запис
with open(os.path.join(OUTPUT_DIR, "posthoc_wilcoxon.txt"), "w", encoding="utf-8") as f:
    f.write("Post-hoc двойни сравнения (Wilcoxon, Bonferroni)\n" + "="*60 + "\n")
    for m in метрики_тежест:
        d = дании_по_метрика[m]
        _, p_f = stats.friedmanchisquare(d.iloc[:, 0], d.iloc[:, 1], d.iloc[:, 2])
        if p_f >= 0.05:
            f.write(f"\n{m}: Friedman незначим.\n")
            continue
        f.write(f"\n--- {m} (Friedman p={p_f:.4f}) ---\n")
        pairs = [(0, 1), (0, 2), (1, 2)]
        names = d.columns
        for i, j in pairs:
            w_stat, w_p = stats.wilcoxon(d.iloc[:, i], d.iloc[:, j])
            sig = "Да" if w_p < alpha_bonf else "Не"
            f.write(f"{names[i]} vs {names[j]}: W={w_stat:.3f}, p={w_p:.4f} -> значима? {sig}\n")

# ====================== 6. КОРЕЛАЦИИ ======================
print("\n=== КОРЕЛАЦИЯ МЕЖДУ %_of_Total И dNBR_Mean ===")
for p in покрития:
    col = f"{p}_%_of_Total"
    r, pv = stats.pearsonr(df[col], df['dNBR_Mean'])
    print(f"{p}: r={r:.3f}, p={pv:.4f}")

# Запис
with open(os.path.join(OUTPUT_DIR, "correlations.txt"), "w", encoding="utf-8") as f:
    f.write("Корелация (Pearson) между %_of_Total и dNBR_Mean\n" + "="*60 + "\n")
    for p in покрития:
        col = f"{p}_%_of_Total"
        r, pv = stats.pearsonr(df[col], df['dNBR_Mean'])
        f.write(f"{p}: r={r:.3f}, p={pv:.4f}\n")

# ====================== 7. ВИЗУАЛИЗАЦИИ ======================
# Boxplots
fig, axes = plt.subplots(1, 3, figsize=(16, 6))
for ax, m in zip(axes, метрики_тежест):
    дании_по_метрика[m].boxplot(ax=ax)
    ax.set_title(f"Разпределение на {m}")
    ax.set_ylabel("% от пикселите на покритието")
    ax.tick_params(axis='x', rotation=15)
plt.suptitle("Boxplots на тежестта по тип земно покритие", fontsize=16)
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, "boxplots_severity.png"), dpi=150)
plt.show()

# Scatter plots
fig, axes = plt.subplots(3, 2, figsize=(14, 12))
for i, p in enumerate(покрития):
    vul_col = f"{p}_Vulnerability_Index"
    pct_col = f"{p}_%_of_Total"
    sns.regplot(x=df['dNBR_Mean'], y=df[vul_col], ax=axes[i, 0], ci=95)
    axes[i, 0].set_title(f"{p}: Vulnerability vs dNBR_Mean")
    sns.regplot(x=df[pct_col], y=df[vul_col], ax=axes[i, 1], ci=95)
    axes[i, 1].set_title(f"{p}: Vulnerability vs %_of_Total")
plt.suptitle("Зависимост на индекса на уязвимост от dNBR и % от площта", fontsize=16)
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, "scatter_vulnerability.png"), dpi=150)
plt.show()

# Heatmap
corr_cols = ['dNBR_Mean', 'Total_Burned_%'] + [f"{p}_%_of_Total" for p in покрития] + [f"{p}_Vulnerability_Index" for p in покрития]
corr_df = df[corr_cols].rename(columns=lambda c: c.replace('/','_').replace(' ','_'))
plt.figure(figsize=(10, 8))
sns.heatmap(corr_df.corr(), annot=True, cmap='RdBu_r', center=0, fmt=".2f")
plt.title("Корелационна матрица на основни променливи")
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, "correlation_heatmap.png"), dpi=150)
plt.show()

# ====================== 8. ЛИНЕЙНА РЕГРЕСИЯ ======================
def calculate_pvalues(X, y, coefficients):
    n, k = X.shape
    y_pred = X @ coefficients
    residuals = y - y_pred
    df_resid = n - k
    sigma2 = np.sum(residuals**2) / df_resid
    cov_matrix = sigma2 * np.linalg.inv(X.T @ X)
    std_errors = np.sqrt(np.diag(cov_matrix))
    t_stats = coefficients / std_errors
    p_values = 2 * (1 - stats.t.cdf(np.abs(t_stats), df=df_resid))
    return p_values, std_errors

def calculate_vif(X):
    vif = []
    n_cols = X.shape[1]
    for i in range(n_cols):
        y_i = X[:, i]
        X_i = np.delete(X, i, axis=1)
        reg = LinearRegression().fit(X_i, y_i)
        r2 = reg.score(X_i, y_i)
        vif.append(1 / (1 - r2))
    return np.array(vif)

print("\n=== ЛИНЕЙНА РЕГРЕСИЯ ЗА ПРЕДСКАЗВАНЕ НА VULNERABILITY INDEX ===")
reg_summary = []

for p in покрития:
    print(f"\n--- Модел за {p} ---")
    target = f"{p}_Vulnerability_Index"
    pct_col = f"{p}_%_of_Total"

    X = df[['dNBR_Mean', 'Total_Burned_%', pct_col]].values
    y = df[target].values
    X_design = np.column_stack([np.ones(X.shape[0]), X])
    var_names = ['const', 'dNBR_Mean', 'Total_Burned_%', pct_col]

    model = LinearRegression().fit(X_design, y)
    coeffs = model.coef_
    y_pred = model.predict(X_design)
    r2 = r2_score(y, y_pred)
    adj_r2 = 1 - (1 - r2) * (len(y) - 1) / (len(y) - X_design.shape[1] - 1)

    pvals, std_errs = calculate_pvalues(X_design, y, coeffs)
    vif_values = calculate_vif(X_design[:, 1:])

    # Отпечатване на резултатите
    print(f"R² = {r2:.4f},  Adj. R² = {adj_r2:.4f}")
    coef_df = pd.DataFrame({
        'Коеф.': coeffs,
        'Стд. грешка': std_errs,
        't-статистика': coeffs / std_errs,
        'p-стойност': pvals
    }, index=var_names)
    display(coef_df.round(4))
    print("VIF (без константа):")
    vif_df = pd.DataFrame({'Променлива': var_names[1:], 'VIF': vif_values})
    display(vif_df.round(2))

    # Диагностични графики
    residuals = y - y_pred
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    stats.probplot(residuals, dist="norm", plot=ax1)
    ax1.set_title(f"QQ-plot - {p}")
    ax2.scatter(y_pred, residuals)
    ax2.axhline(0, color='red', linestyle='--')
    ax2.set_xlabel("Предсказани стойности")
    ax2.set_ylabel("Остатъци")
    ax2.set_title(f"Остатъци vs предсказани - {p}")
    plt.suptitle(f"Диагностика на регресионен модел за {p}", fontsize=14)
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIR, f"diagnostics_{p.replace('/','_')}.png"), dpi=150)
    plt.show()

    reg_summary.append(f"{p}: R² = {r2:.3f}, Adj.R² = {adj_r2:.3f}")

    # Запис в текстов файл (подробно)
    out_path = os.path.join(OUTPUT_DIR, f"regression_{p.replace('/','_')}.txt")
    with open(out_path, "w", encoding="utf-8") as f:
        f.write(f"Линейна регресия за {p}\n" + "="*60 + "\n")
        f.write(f"R² = {r2:.4f},  Adj. R² = {adj_r2:.4f}\n\n")
        f.write("Коефициенти:\n")
        f.write(f"{'Променлива':<25} {'Коеф.':>10} {'Стд. грешка':>12} {'t-стат.':>10} {'p-стойност':>12}\n")
        for name, coef, se, pv in zip(var_names, coeffs, std_errs, pvals):
            f.write(f"{name:<25} {coef:>10.4f} {se:>12.4f} {coef/se:>10.4f} {pv:>12.4f}\n")
        f.write("\nVIF (без константа):\n")
        for vname, vif in zip(var_names[1:], vif_values):
            f.write(f"{vname:<25} {vif:>10.2f}\n")

# Обобщение на регресиите
print("\n=== ОБОБЩЕНИЕ НА РЕГРЕСИОННИТЕ МОДЕЛИ ===")
for line in reg_summary:
    print(line)

with open(os.path.join(OUTPUT_DIR, "regression_summary.txt"), "w", encoding="utf-8") as f:
    f.write("Кратко обобщение на регресионните модели\n" + "="*60 + "\n")
    for line in reg_summary:
        f.write(line + "\n")

print(f"\n✅ Всички резултати са записани в папка: {OUTPUT_DIR}")
# Out:
# === РАЗМЕРНОСТ И ИНФОРМАЦИЯ ЗА ДАННИТЕ ===
# Shape: (15, 75)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 75 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Fire_ID                                        15 non-null     int64
#  1   Fire_Date                                      15 non-null     object
#  2   Before_Date                                    15 non-null     object
#  3   After_Date                                     15 non-null     object
#  4   Before_File                                    15 non-null     object
#  5   After_File                                     15 non-null     object
#  6   Total_Valid_Pixels                             15 non-null     int64
#  7   Excluded_Pixels                                15 non-null     int64
#  8   Excluded_Percentage                            15 non-null     float64
#  9   Total_Burned_Pixels                            15 non-null     int64
#  10  Total_Burned_%                                 15 non-null     float64
#  11  Enhanced_Regrowth_%                            15 non-null     float64
#  12  Unburned_%                                     15 non-null     float64
#  13  Low_Severity_%                                 15 non-null     float64
#  14  Moderate_Severity_%                            15 non-null     float64
#  15  High_Severity_%                                15 non-null     float64
#  16  Most_Common_Severity                           15 non-null     object
#  17  Fire_Impact_Assessment                         15 non-null     object
#  18  Damage_Assessment                              15 non-null     object
#  19  PreFire_NBR_Mean                               15 non-null     float64
#  20  PostFire_NBR_Mean                              15 non-null     float64
#  21  dNBR_Mean                                      15 non-null     float64
#  22  Has_LandCover_Data                             15 non-null     object
#  23  Dominant_LandCover                             15 non-null     object
#  24  Dominant_LandCover_%                           15 non-null     float64
#  25  Most_Vulnerable_HighSeverity                   15 non-null     object
#  26  Most_Vulnerable_HighSeverity_%                 15 non-null     float64
#  27  Most_Vulnerable_ModerateSeverity               15 non-null     object
#  28  Most_Vulnerable_ModerateSeverity_%             15 non-null     float64
#  29  Most_Vulnerable_LowSeverity                    15 non-null     object
#  30  Most_Vulnerable_LowSeverity_%                  15 non-null     float64
#  31  Field/Agriculture_Pixels                       15 non-null     int64
#  32  Field/Agriculture_%_of_Total                   15 non-null     float64
#  33  Field/Agriculture_EnhancedRegrowth_%           15 non-null     float64
#  34  Field/Agriculture_Unburned_%                   15 non-null     float64
#  35  Field/Agriculture_LowSeverity_%                15 non-null     float64
#  36  Field/Agriculture_ModerateSeverity_%           15 non-null     float64
#  37  Field/Agriculture_HighSeverity_%               15 non-null     float64
#  38  Field/Agriculture_ModerateHigh_%               15 non-null     float64
#  39  Field/Agriculture_LowModerateHigh_%            15 non-null     float64
#  40  Field/Agriculture_Vulnerability_Index          15 non-null     float64
#  41  Coniferous_Forest_Pixels                       15 non-null     int64
#  42  Coniferous_Forest_%_of_Total                   15 non-null     float64
#  43  Coniferous_Forest_EnhancedRegrowth_%           15 non-null     float64
#  44  Coniferous_Forest_Unburned_%                   15 non-null     float64
#  45  Coniferous_Forest_LowSeverity_%                15 non-null     float64
#  46  Coniferous_Forest_ModerateSeverity_%           15 non-null     float64
#  47  Coniferous_Forest_HighSeverity_%               15 non-null     float64
#  48  Coniferous_Forest_ModerateHigh_%               15 non-null     float64
#  49  Coniferous_Forest_LowModerateHigh_%            15 non-null     float64
#  50  Coniferous_Forest_Vulnerability_Index          15 non-null     float64
#  51  Deciduous_Forest_Pixels                        15 non-null     int64
#  52  Deciduous_Forest_%_of_Total                    15 non-null     float64
#  53  Deciduous_Forest_EnhancedRegrowth_%            15 non-null     float64
#  54  Deciduous_Forest_Unburned_%                    15 non-null     float64
#  55  Deciduous_Forest_LowSeverity_%                 15 non-null     float64
#  56  Deciduous_Forest_ModerateSeverity_%            15 non-null     float64
#  57  Deciduous_Forest_HighSeverity_%                15 non-null     float64
#  58  Deciduous_Forest_ModerateHigh_%                15 non-null     float64
#  59  Deciduous_Forest_LowModerateHigh_%             15 non-null     float64
#  60  Deciduous_Forest_Vulnerability_Index           15 non-null     float64
#  61  Water_Pixels                                   15 non-null     int64
#  62  Water_%_of_Total                               15 non-null     int64
#  63  Water_EnhancedRegrowth_%                       15 non-null     int64
#  64  Water_Unburned_%                               15 non-null     int64
#  65  Water_LowSeverity_%                            15 non-null     int64
#  66  Water_ModerateSeverity_%                       15 non-null     int64
#  67  Water_HighSeverity_%                           15 non-null     int64
#  68  Bare_and_Urban_Territories_Pixels              15 non-null     int64
#  69  Bare_and_Urban_Territories_%_of_Total          15 non-null     int64
#  70  Bare_and_Urban_Territories_EnhancedRegrowth_%  15 non-null     int64
#  71  Bare_and_Urban_Territories_Unburned_%          15 non-null     int64
#  72  Bare_and_Urban_Territories_LowSeverity_%       15 non-null     int64
#  73  Bare_and_Urban_Territories_ModerateSeverity_%  15 non-null     int64
#  74  Bare_and_Urban_Territories_HighSeverity_%      15 non-null     int64
# dtypes: float64(41), int64(21), object(13)
# memory usage: 8.9+ KB
# === ДЕСКРИПТИВНА СТАТИСТИКА ===
#
# --- ModerateSeverity_% ---
#        ModerateSeverity  Forest_ModerateSeverity  Forest_ModerateSeverity
# count             15.00                    15.00                    15.00
# mean               2.87                     3.16                     5.33
# std                2.44                     3.38                     8.15
# min                0.08                     0.20                     0.00
# 25%                1.15                     0.71                     0.01
# 50%                2.11                     2.22                     1.22
# 75%                3.60                     4.68                     7.94
# max                7.91                    12.82                    24.02
# --- HighSeverity_% ---
#        HighSeverity  Forest_HighSeverity  Forest_HighSeverity
# count         15.00                15.00                15.00
# mean           2.06                 2.93                 2.54
# std            2.18                 3.46                 3.02
# min            0.01                 0.03                 0.00
# 25%            0.18                 0.22                 0.01
# 50%            1.63                 1.11                 1.34
# 75%            3.22                 4.34                 4.18
# max            6.47                 9.81                 8.58
# --- ModerateHigh_% ---
#        ModerateHigh  Forest_ModerateHigh  Forest_ModerateHigh
# count         15.00                15.00                15.00
# mean           4.93                 6.09                 7.86
# std            3.69                 6.38                10.96
# min            0.14                 0.42                 0.00
# 25%            1.77                 0.93                 0.02
# 50%            4.52                 3.70                 2.27
# 75%            7.16                 9.64                12.37
# max           13.11                21.54                32.59
# === FRIEDMAN TEST ===
# ModerateSeverity_%: stat=0.000, p=1.0000 -> значима разлика? НЕ
# HighSeverity_%: stat=6.400, p=0.0408 -> значима разлика? ДА
# ModerateHigh_%: stat=0.133, p=0.9355 -> значима разлика? НЕ
#
# === POST-HOC (WILCOXON С BONFERRONI КОРЕКЦИЯ) ===
# ModerateSeverity_%: Friedman незначим – пропускаме post-hoc.
#
# --- HighSeverity_% (Friedman p=0.0408) ---
# HighSeverity vs Forest_HighSeverity: W=31.000, p=0.1070 -> значима? НЕ
# HighSeverity vs Forest_HighSeverity: W=48.000, p=0.5245 -> значима? НЕ
# Forest_HighSeverity vs Forest_HighSeverity: W=33.000, p=0.1354 -> значима? НЕ
# ModerateHigh_%: Friedman незначим – пропускаме post-hoc.
#
# === КОРЕЛАЦИЯ МЕЖДУ %_of_Total И dNBR_Mean ===
# Field/Agriculture: r=0.418, p=0.1213
# Coniferous_Forest: r=-0.557, p=0.0309
# Deciduous_Forest: r=-0.147, p=0.6022
# === ЛИНЕЙНА РЕГРЕСИЯ ЗА ПРЕДСКАЗВАНЕ НА VULNERABILITY INDEX ===
#
# --- Модел за Field/Agriculture ---
# R² = 0.3403,  Adj. R² = 0.0764
#                                Коеф.  Стд. грешка  t-статистика  p-стойност
# const                         0.0000       2.0389        0.0000      1.0000
# dNBR_Mean                     4.9389      51.5180        0.0959      0.9253
# Total_Burned_%               -0.0176       0.1190       -0.1475      0.8854
# Field/Agriculture_%_of_Total -0.0036       0.0329       -0.1106      0.9139
# VIF (без константа):
#                      Променлива    VIF
# 0                     dNBR_Mean   9.32
# 1                Total_Burned_%  12.08
# 2  Field/Agriculture_%_of_Total   2.03
# --- Модел за Coniferous_Forest ---
# R² = 0.3424,  Adj. R² = 0.0793
#                                 Коеф.  Стд. грешка  t-статистика  p-стойност
# const                          0.0000       2.3868        0.0000      1.0000
# dNBR_Mean                     10.4269      51.2762        0.2033      0.8426
# Total_Burned_%                -0.0285       0.1091       -0.2613      0.7987
# Coniferous_Forest_%_of_Total  -0.0161       0.0626       -0.2575      0.8015
# VIF (без константа):
#                      Променлива   VIF
# 0                     dNBR_Mean  7.21
# 1                Total_Burned_%  7.94
# 2  Coniferous_Forest_%_of_Total  1.60
# --- Модел за Deciduous_Forest ---
# R² = 0.7716,  Adj. R² = 0.6802
#                                Коеф.  Стд. грешка  t-статистика  p-стойност
# const                         0.0000       0.4336        0.0000      1.0000
# dNBR_Mean                    39.5579      15.2893        2.5873      0.0253
# Total_Burned_%               -0.0849       0.0324       -2.6200      0.0238
# Deciduous_Forest_%_of_Total   0.0178       0.0120        1.4836      0.1660
# VIF (без константа):
#                     Променлива   VIF
# 0                    dNBR_Mean  8.84
# 1               Total_Burned_%  9.65
# 2  Deciduous_Forest_%_of_Total  1.37
# === ОБОБЩЕНИЕ НА РЕГРЕСИОННИТЕ МОДЕЛИ ===
# Field/Agriculture: R² = 0.340, Adj.R² = 0.076
# Coniferous_Forest: R² = 0.342, Adj.R² = 0.079
# Deciduous_Forest: R² = 0.772, Adj.R² = 0.680
#
# ✅ Всички резултати са записани в папка: D:\data\master_thesis\exports\sentinel2_fire_images\nbr_analysis\analysis_output
